# %%
#This file contains raw cache implementation with a simulated testing senario along with tweet data example. 
# The cache-checkpoint.json file is also attach for reference.

# %%
import time
class LRUCache1:
    def __init__(self, capacity, checkpoint_interval):
        self.capacity = capacity
        self.cache = {}
        self.access_times = {}
        self.checkpoint_interval = checkpoint_interval
        self.last_checkpoint_time = time.time()

    def get(self, key):
        if key in self.cache:
            self.access_times[key] = time.time()
            return self.cache[key]
        return None
    
    def put(self, key, value):
        if len(self.cache) >= self.capacity:
            self.evict_least_recently_used()

        self.cache[key] = value
        self.access_times[key] = time.time()

        if time.time() - self.last_checkpoint_time > self.checkpoint_interval:
            self.checkpoint()
            self.last_checkpoint_time = time.time()

    def process_tweets_for_cache(self, tweets): #This function goes in with search application functions.
        for tweet in tweets:
            # Exclude the _id field from the tweet
            tweet_without_id = {key: value for key, value in tweet.items() if key != '_id'}
            self.put(tweet_without_id['Tweet_Id'], tweet_without_id)
        #self.checkpoint()
        
    def evict_least_recently_used(self):
        if not self.cache:
            return
        oldest_key = min(self.access_times, key=self.access_times.get)
        del self.cache[oldest_key]
        del self.access_times[oldest_key]

    def checkpoint(self):
        with open('cache_check-point.json', 'w') as f:
            json.dump({'cache': self.cache, 'access_times': self.access_times}, f)
        self.last_checkpoint_time = time.time()


    def load_checkpoint(self):
        try:
            with open('cache_check-point.json', 'r') as f:
                data = json.load(f)
                self.cache = data['cache']
                self.access_times = data['access_times']
                self.last_checkpoint_time = time.time()
        except FileNotFoundError:
            pass
        
    def search_tweet(self, tweet_id):
        for key, value in self.cache.items():
            if key == tweet_id:
                return value
        return None

# %%
# Simulated implementation
import random
import string

# Function to generate a random tweet
def generate_tweet(user_id):
    tweet_id = ''.join(random.choices(string.ascii_letters + string.digits, k=8))
    return {'Tid': tweet_id, 'user_id': user_id, 'text': f'Tweet {tweet_id}'}

tweets = []
for i in range(10000):
    for _ in range(500):
        tweets.append(generate_tweet(i))


cache = LRUCache1(capacity=200, checkpoint_interval=10)

for tweet in tweets:
    Tid = tweet['Tid']
    if Tid not in cache.cache:
        cache.put(Tid, [tweet])

print("Cache contents:")
for Tid, tweet in cache.cache.items():
    print(f"Tweet Id: {Tid}, Tweet: {[tweet]}")
# Out:
# Cache contents:
# Tweet Id: dQ49K0pM, Tweet: [[{'Tid': 'dQ49K0pM', 'user_id': 9999, 'text': 'Tweet dQ49K0pM'}]]
# Tweet Id: 7gPNY0jD, Tweet: [[{'Tid': '7gPNY0jD', 'user_id': 9999, 'text': 'Tweet 7gPNY0jD'}]]
# Tweet Id: w8OXGCZ7, Tweet: [[{'Tid': 'w8OXGCZ7', 'user_id': 9999, 'text': 'Tweet w8OXGCZ7'}]]
# Tweet Id: WYnMPCbZ, Tweet: [[{'Tid': 'WYnMPCbZ', 'user_id': 9999, 'text': 'Tweet WYnMPCbZ'}]]
# Tweet Id: YOswlbD5, Tweet: [[{'Tid': 'YOswlbD5', 'user_id': 9999, 'text': 'Tweet YOswlbD5'}]]
# Tweet Id: J10uFzpO, Tweet: [[{'Tid': 'J10uFzpO', 'user_id': 9999, 'text': 'Tweet J10uFzpO'}]]
# Tweet Id: geZFLbXE, Tweet: [[{'Tid': 'geZFLbXE', 'user_id': 9999, 'text': 'Tweet geZFLbXE'}]]
# Tweet Id: NeJcgZYp, Tweet: [[{'Tid': 'NeJcgZYp', 'user_id': 9999, 'text': 'Tweet NeJcgZYp'}]]
# Tweet Id: wQKadTsj, Tweet: [[{'Tid': 'wQKadTsj', 'user_id': 9999, 'text': 'Tweet wQKadTsj'}]]
# Tweet Id: 5kwLka6i, Tweet: [[{'Tid': '5kwLka6i', 'user_id': 9999, 'text': 'Tweet 5kwLka6i'}]]
# Tweet Id: 896puEv6, Tweet: [[{'Tid': '896puEv6', 'user_id': 9999, 'text': 'Tweet 896puEv6'}]]
# Tweet Id: YZOJsxdk, Tweet: [[{'Tid': 'YZOJsxdk', 'user_id': 9999, 'text': 'Tweet YZOJsxdk'}]]
# Tweet Id: 8VFCNUVZ, Tweet: [[{'Tid': '8VFCNUVZ', 'user_id': 9999, 'text': 'Tweet 8VFCNUVZ'}]]
# Tweet Id: laV8qjhr, Tweet: [[{'Tid': 'laV8qjhr', 'user_id': 9999, 'text': 'Tweet laV8qjhr'}]]
# Tweet Id: u01cDBtI, Tweet: [[{'Tid': 'u01cDBtI', 'user_id': 9999, 'text': 'Tweet u01cDBtI'}]]
# Tweet Id: pr9yZNUo, Tweet: [[{'Tid': 'pr9yZNUo', 'user_id': 9999, 'text': 'Tweet pr9yZNUo'}]]
# Tweet Id: R5FExiyH, Tweet: [[{'Tid': 'R5FExiyH', 'user_id': 9999, 'text': 'Tweet R5FExiyH'}]]
# Tweet Id: SaXjUdHz, Tweet: [[{'Tid': 'SaXjUdHz', 'user_id': 9999, 'text': 'Tweet SaXjUdHz'}]]
# Tweet Id: mkTxLv91, Tweet: [[{'Tid': 'mkTxLv91', 'user_id': 9999, 'text': 'Tweet mkTxLv91'}]]
# Tweet Id: 5NsP28aE, Tweet: [[{'Tid': '5NsP28aE', 'user_id': 9999, 'text': 'Tweet 5NsP28aE'}]]
# Tweet Id: lKYqj1ER, Tweet: [[{'Tid': 'lKYqj1ER', 'user_id': 9999, 'text': 'Tweet lKYqj1ER'}]]
# Tweet Id: ERbSGEex, Tweet: [[{'Tid': 'ERbSGEex', 'user_id': 9999, 'text': 'Tweet ERbSGEex'}]]
# Tweet Id: pXYs5RKA, Tweet: [[{'Tid': 'pXYs5RKA', 'user_id': 9999, 'text': 'Tweet pXYs5RKA'}]]
# Tweet Id: 7S7yKwIe, Tweet: [[{'Tid': '7S7yKwIe', 'user_id': 9999, 'text': 'Tweet 7S7yKwIe'}]]
# Tweet Id: 3YwZNKMg, Tweet: [[{'Tid': '3YwZNKMg', 'user_id': 9999, 'text': 'Tweet 3YwZNKMg'}]]
# Tweet Id: PULXH2Pd, Tweet: [[{'Tid': 'PULXH2Pd', 'user_id': 9999, 'text': 'Tweet PULXH2Pd'}]]
# Tweet Id: fss99StV, Tweet: [[{'Tid': 'fss99StV', 'user_id': 9999, 'text': 'Tweet fss99StV'}]]
# Tweet Id: vjXPlzem, Tweet: [[{'Tid': 'vjXPlzem', 'user_id': 9999, 'text': 'Tweet vjXPlzem'}]]
# Tweet Id: C7mCCYbF, Tweet: [[{'Tid': 'C7mCCYbF', 'user_id': 9999, 'text': 'Tweet C7mCCYbF'}]]
# Tweet Id: GbPcfnDT, Tweet: [[{'Tid': 'GbPcfnDT', 'user_id': 9999, 'text': 'Tweet GbPcfnDT'}]]
# Tweet Id: Ak2AVVZP, Tweet: [[{'Tid': 'Ak2AVVZP', 'user_id': 9999, 'text': 'Tweet Ak2AVVZP'}]]
# Tweet Id: BTOA2s6z, Tweet: [[{'Tid': 'BTOA2s6z', 'user_id': 9999, 'text': 'Tweet BTOA2s6z'}]]
# Tweet Id: ZMST9gvj, Tweet: [[{'Tid': 'ZMST9gvj', 'user_id': 9999, 'text': 'Tweet ZMST9gvj'}]]
# Tweet Id: ZZYqORYM, Tweet: [[{'Tid': 'ZZYqORYM', 'user_id': 9999, 'text': 'Tweet ZZYqORYM'}]]
# Tweet Id: XNUsjHWQ, Tweet: [[{'Tid': 'XNUsjHWQ', 'user_id': 9999, 'text': 'Tweet XNUsjHWQ'}]]
# Tweet Id: Sb5tDl9t, Tweet: [[{'Tid': 'Sb5tDl9t', 'user_id': 9999, 'text': 'Tweet Sb5tDl9t'}]]
# Tweet Id: q9AGr9hJ, Tweet: [[{'Tid': 'q9AGr9hJ', 'user_id': 9999, 'text': 'Tweet q9AGr9hJ'}]]
# Tweet Id: UIkktfpz, Tweet: [[{'Tid': 'UIkktfpz', 'user_id': 9999, 'text': 'Tweet UIkktfpz'}]]
# Tweet Id: azlBOPSg, Tweet: [[{'Tid': 'azlBOPSg', 'user_id': 9999, 'text': 'Tweet azlBOPSg'}]]
# Tweet Id: NpbvLB4j, Tweet: [[{'Tid': 'NpbvLB4j', 'user_id': 9999, 'text': 'Tweet NpbvLB4j'}]]
# Tweet Id: ary1cgam, Tweet: [[{'Tid': 'ary1cgam', 'user_id': 9999, 'text': 'Tweet ary1cgam'}]]
# Tweet Id: 573u2qHW, Tweet: [[{'Tid': '573u2qHW', 'user_id': 9999, 'text': 'Tweet 573u2qHW'}]]
# Tweet Id: hhsTlNmV, Tweet: [[{'Tid': 'hhsTlNmV', 'user_id': 9999, 'text': 'Tweet hhsTlNmV'}]]
# Tweet Id: wyhVJ8vx, Tweet: [[{'Tid': 'wyhVJ8vx', 'user_id': 9999, 'text': 'Tweet wyhVJ8vx'}]]
# Tweet Id: f0gDeNSa, Tweet: [[{'Tid': 'f0gDeNSa', 'user_id': 9999, 'text': 'Tweet f0gDeNSa'}]]
# Tweet Id: 21BBFjVu, Tweet: [[{'Tid': '21BBFjVu', 'user_id': 9999, 'text': 'Tweet 21BBFjVu'}]]
# Tweet Id: Mlo0w2fS, Tweet: [[{'Tid': 'Mlo0w2fS', 'user_id': 9999, 'text': 'Tweet Mlo0w2fS'}]]
# Tweet Id: nceC1EN6, Tweet: [[{'Tid': 'nceC1EN6', 'user_id': 9999, 'text': 'Tweet nceC1EN6'}]]
# Tweet Id: PWqoeRMw, Tweet: [[{'Tid': 'PWqoeRMw', 'user_id': 9999, 'text': 'Tweet PWqoeRMw'}]]
# Tweet Id: UBUy8Ao4, Tweet: [[{'Tid': 'UBUy8Ao4', 'user_id': 9999, 'text': 'Tweet UBUy8Ao4'}]]
# Tweet Id: qmnsfi5W, Tweet: [[{'Tid': 'qmnsfi5W', 'user_id': 9999, 'text': 'Tweet qmnsfi5W'}]]
# Tweet Id: N6SqOdgB, Tweet: [[{'Tid': 'N6SqOdgB', 'user_id': 9999, 'text': 'Tweet N6SqOdgB'}]]
# Tweet Id: 3FZbx905, Tweet: [[{'Tid': '3FZbx905', 'user_id': 9999, 'text': 'Tweet 3FZbx905'}]]
# Tweet Id: Dsw4VvNy, Tweet: [[{'Tid': 'Dsw4VvNy', 'user_id': 9999, 'text': 'Tweet Dsw4VvNy'}]]
# Tweet Id: kJrtnTkH, Tweet: [[{'Tid': 'kJrtnTkH', 'user_id': 9999, 'text': 'Tweet kJrtnTkH'}]]
# Tweet Id: b8W3EDT0, Tweet: [[{'Tid': 'b8W3EDT0', 'user_id': 9999, 'text': 'Tweet b8W3EDT0'}]]
# Tweet Id: l7Isgm7K, Tweet: [[{'Tid': 'l7Isgm7K', 'user_id': 9999, 'text': 'Tweet l7Isgm7K'}]]
# Tweet Id: 9qp28cAE, Tweet: [[{'Tid': '9qp28cAE', 'user_id': 9999, 'text': 'Tweet 9qp28cAE'}]]
# Tweet Id: TwWrQLT1, Tweet: [[{'Tid': 'TwWrQLT1', 'user_id': 9999, 'text': 'Tweet TwWrQLT1'}]]
# Tweet Id: oexKkihu, Tweet: [[{'Tid': 'oexKkihu', 'user_id': 9999, 'text': 'Tweet oexKkihu'}]]
# Tweet Id: WvhoIF05, Tweet: [[{'Tid': 'WvhoIF05', 'user_id': 9999, 'text': 'Tweet WvhoIF05'}]]
# Tweet Id: l0JUdk5Y, Tweet: [[{'Tid': 'l0JUdk5Y', 'user_id': 9999, 'text': 'Tweet l0JUdk5Y'}]]
# Tweet Id: Y3rOeWJK, Tweet: [[{'Tid': 'Y3rOeWJK', 'user_id': 9999, 'text': 'Tweet Y3rOeWJK'}]]
# Tweet Id: gWBJaqaY, Tweet: [[{'Tid': 'gWBJaqaY', 'user_id': 9999, 'text': 'Tweet gWBJaqaY'}]]
# Tweet Id: lYe8kv4G, Tweet: [[{'Tid': 'lYe8kv4G', 'user_id': 9999, 'text': 'Tweet lYe8kv4G'}]]
# Tweet Id: HY4HWr8R, Tweet: [[{'Tid': 'HY4HWr8R', 'user_id': 9999, 'text': 'Tweet HY4HWr8R'}]]
# Tweet Id: EGKNzYZK, Tweet: [[{'Tid': 'EGKNzYZK', 'user_id': 9999, 'text': 'Tweet EGKNzYZK'}]]
# Tweet Id: vdVbYWzE, Tweet: [[{'Tid': 'vdVbYWzE', 'user_id': 9999, 'text': 'Tweet vdVbYWzE'}]]
# Tweet Id: oOMSidKf, Tweet: [[{'Tid': 'oOMSidKf', 'user_id': 9999, 'text': 'Tweet oOMSidKf'}]]
# Tweet Id: i6Go2x0s, Tweet: [[{'Tid': 'i6Go2x0s', 'user_id': 9999, 'text': 'Tweet i6Go2x0s'}]]
# Tweet Id: Gy2lH5yM, Tweet: [[{'Tid': 'Gy2lH5yM', 'user_id': 9999, 'text': 'Tweet Gy2lH5yM'}]]
# Tweet Id: rtbfAKep, Tweet: [[{'Tid': 'rtbfAKep', 'user_id': 9999, 'text': 'Tweet rtbfAKep'}]]
# Tweet Id: L2XWLNfQ, Tweet: [[{'Tid': 'L2XWLNfQ', 'user_id': 9999, 'text': 'Tweet L2XWLNfQ'}]]
# Tweet Id: lLoeMdSL, Tweet: [[{'Tid': 'lLoeMdSL', 'user_id': 9999, 'text': 'Tweet lLoeMdSL'}]]
# Tweet Id: M15HXYwe, Tweet: [[{'Tid': 'M15HXYwe', 'user_id': 9999, 'text': 'Tweet M15HXYwe'}]]
# Tweet Id: wtIgT5E1, Tweet: [[{'Tid': 'wtIgT5E1', 'user_id': 9999, 'text': 'Tweet wtIgT5E1'}]]
# Tweet Id: XSIyssVq, Tweet: [[{'Tid': 'XSIyssVq', 'user_id': 9999, 'text': 'Tweet XSIyssVq'}]]
# Tweet Id: MxLMb0Cm, Tweet: [[{'Tid': 'MxLMb0Cm', 'user_id': 9999, 'text': 'Tweet MxLMb0Cm'}]]
# Tweet Id: NDoG2LZ3, Tweet: [[{'Tid': 'NDoG2LZ3', 'user_id': 9999, 'text': 'Tweet NDoG2LZ3'}]]
# Tweet Id: 73eQFmL1, Tweet: [[{'Tid': '73eQFmL1', 'user_id': 9999, 'text': 'Tweet 73eQFmL1'}]]
# Tweet Id: pxgkre6E, Tweet: [[{'Tid': 'pxgkre6E', 'user_id': 9999, 'text': 'Tweet pxgkre6E'}]]
# Tweet Id: y6ZkNSsD, Tweet: [[{'Tid': 'y6ZkNSsD', 'user_id': 9999, 'text': 'Tweet y6ZkNSsD'}]]
# Tweet Id: V9iZM4z5, Tweet: [[{'Tid': 'V9iZM4z5', 'user_id': 9999, 'text': 'Tweet V9iZM4z5'}]]
# Tweet Id: gfukmVWB, Tweet: [[{'Tid': 'gfukmVWB', 'user_id': 9999, 'text': 'Tweet gfukmVWB'}]]
# Tweet Id: Y6pnQbsa, Tweet: [[{'Tid': 'Y6pnQbsa', 'user_id': 9999, 'text': 'Tweet Y6pnQbsa'}]]
# Tweet Id: KOXqvJ0M, Tweet: [[{'Tid': 'KOXqvJ0M', 'user_id': 9999, 'text': 'Tweet KOXqvJ0M'}]]
# Tweet Id: CAaR1Ab5, Tweet: [[{'Tid': 'CAaR1Ab5', 'user_id': 9999, 'text': 'Tweet CAaR1Ab5'}]]
# Tweet Id: Es79SjGO, Tweet: [[{'Tid': 'Es79SjGO', 'user_id': 9999, 'text': 'Tweet Es79SjGO'}]]
# Tweet Id: TddMGdWL, Tweet: [[{'Tid': 'TddMGdWL', 'user_id': 9999, 'text': 'Tweet TddMGdWL'}]]
# Tweet Id: IXZBtNo7, Tweet: [[{'Tid': 'IXZBtNo7', 'user_id': 9999, 'text': 'Tweet IXZBtNo7'}]]
# Tweet Id: sWts5Q19, Tweet: [[{'Tid': 'sWts5Q19', 'user_id': 9999, 'text': 'Tweet sWts5Q19'}]]
# Tweet Id: 2QhQ0VCm, Tweet: [[{'Tid': '2QhQ0VCm', 'user_id': 9999, 'text': 'Tweet 2QhQ0VCm'}]]
# Tweet Id: QxLom4RK, Tweet: [[{'Tid': 'QxLom4RK', 'user_id': 9999, 'text': 'Tweet QxLom4RK'}]]
# Tweet Id: 1JMOycwa, Tweet: [[{'Tid': '1JMOycwa', 'user_id': 9999, 'text': 'Tweet 1JMOycwa'}]]
# Tweet Id: 3Q4ZG8cD, Tweet: [[{'Tid': '3Q4ZG8cD', 'user_id': 9999, 'text': 'Tweet 3Q4ZG8cD'}]]
# Tweet Id: cGcWCYZY, Tweet: [[{'Tid': 'cGcWCYZY', 'user_id': 9999, 'text': 'Tweet cGcWCYZY'}]]
# Tweet Id: HSCfUurE, Tweet: [[{'Tid': 'HSCfUurE', 'user_id': 9999, 'text': 'Tweet HSCfUurE'}]]
# Tweet Id: AQqDbUwp, Tweet: [[{'Tid': 'AQqDbUwp', 'user_id': 9999, 'text': 'Tweet AQqDbUwp'}]]
# Tweet Id: KXNeLgsK, Tweet: [[{'Tid': 'KXNeLgsK', 'user_id': 9999, 'text': 'Tweet KXNeLgsK'}]]
# Tweet Id: H11ENcFW, Tweet: [[{'Tid': 'H11ENcFW', 'user_id': 9999, 'text': 'Tweet H11ENcFW'}]]
# Tweet Id: 6FXuaOpT, Tweet: [[{'Tid': '6FXuaOpT', 'user_id': 9999, 'text': 'Tweet 6FXuaOpT'}]]
# Tweet Id: cj9Tv1XZ, Tweet: [[{'Tid': 'cj9Tv1XZ', 'user_id': 9999, 'text': 'Tweet cj9Tv1XZ'}]]
# Tweet Id: Kpqr0AyM, Tweet: [[{'Tid': 'Kpqr0AyM', 'user_id': 9999, 'text': 'Tweet Kpqr0AyM'}]]
# Tweet Id: xJKkEfFj, Tweet: [[{'Tid': 'xJKkEfFj', 'user_id': 9999, 'text': 'Tweet xJKkEfFj'}]]
# Tweet Id: 4chtmQ6z, Tweet: [[{'Tid': '4chtmQ6z', 'user_id': 9999, 'text': 'Tweet 4chtmQ6z'}]]
# Tweet Id: te3vu9Kg, Tweet: [[{'Tid': 'te3vu9Kg', 'user_id': 9999, 'text': 'Tweet te3vu9Kg'}]]
# Tweet Id: IOqzWmCh, Tweet: [[{'Tid': 'IOqzWmCh', 'user_id': 9999, 'text': 'Tweet IOqzWmCh'}]]
# Tweet Id: qDhIN6cx, Tweet: [[{'Tid': 'qDhIN6cx', 'user_id': 9999, 'text': 'Tweet qDhIN6cx'}]]
# Tweet Id: UhBU3cOQ, Tweet: [[{'Tid': 'UhBU3cOQ', 'user_id': 9999, 'text': 'Tweet UhBU3cOQ'}]]
# Tweet Id: NvmWoac2, Tweet: [[{'Tid': 'NvmWoac2', 'user_id': 9999, 'text': 'Tweet NvmWoac2'}]]
# Tweet Id: WerxzDRt, Tweet: [[{'Tid': 'WerxzDRt', 'user_id': 9999, 'text': 'Tweet WerxzDRt'}]]
# Tweet Id: nWSSBE06, Tweet: [[{'Tid': 'nWSSBE06', 'user_id': 9999, 'text': 'Tweet nWSSBE06'}]]
# Tweet Id: GTnbsMmw, Tweet: [[{'Tid': 'GTnbsMmw', 'user_id': 9999, 'text': 'Tweet GTnbsMmw'}]]
# Tweet Id: csFsLaKJ, Tweet: [[{'Tid': 'csFsLaKJ', 'user_id': 9999, 'text': 'Tweet csFsLaKJ'}]]
# Tweet Id: BHya9Stg, Tweet: [[{'Tid': 'BHya9Stg', 'user_id': 9999, 'text': 'Tweet BHya9Stg'}]]
# Tweet Id: pyf2zrOC, Tweet: [[{'Tid': 'pyf2zrOC', 'user_id': 9999, 'text': 'Tweet pyf2zrOC'}]]
# Tweet Id: iisGxBNo, Tweet: [[{'Tid': 'iisGxBNo', 'user_id': 9999, 'text': 'Tweet iisGxBNo'}]]
# Tweet Id: afUTSwXe, Tweet: [[{'Tid': 'afUTSwXe', 'user_id': 9999, 'text': 'Tweet afUTSwXe'}]]
# Tweet Id: dRDR3Uvn, Tweet: [[{'Tid': 'dRDR3Uvn', 'user_id': 9999, 'text': 'Tweet dRDR3Uvn'}]]
# Tweet Id: jUCXFReI, Tweet: [[{'Tid': 'jUCXFReI', 'user_id': 9999, 'text': 'Tweet jUCXFReI'}]]
# Tweet Id: d8A8VVxA, Tweet: [[{'Tid': 'd8A8VVxA', 'user_id': 9999, 'text': 'Tweet d8A8VVxA'}]]
# Tweet Id: QJwGbYjA, Tweet: [[{'Tid': 'QJwGbYjA', 'user_id': 9999, 'text': 'Tweet QJwGbYjA'}]]
# Tweet Id: IZZTzkNS, Tweet: [[{'Tid': 'IZZTzkNS', 'user_id': 9999, 'text': 'Tweet IZZTzkNS'}]]
# Tweet Id: CTTyT95c, Tweet: [[{'Tid': 'CTTyT95c', 'user_id': 9999, 'text': 'Tweet CTTyT95c'}]]
# Tweet Id: 9wSsrgAE, Tweet: [[{'Tid': '9wSsrgAE', 'user_id': 9999, 'text': 'Tweet 9wSsrgAE'}]]
# Tweet Id: cntcTWu7, Tweet: [[{'Tid': 'cntcTWu7', 'user_id': 9999, 'text': 'Tweet cntcTWu7'}]]
# Tweet Id: UsHhZjJh, Tweet: [[{'Tid': 'UsHhZjJh', 'user_id': 9999, 'text': 'Tweet UsHhZjJh'}]]
# Tweet Id: z9U42R8u, Tweet: [[{'Tid': 'z9U42R8u', 'user_id': 9999, 'text': 'Tweet z9U42R8u'}]]
# Tweet Id: MlfFPj1U, Tweet: [[{'Tid': 'MlfFPj1U', 'user_id': 9999, 'text': 'Tweet MlfFPj1U'}]]
# Tweet Id: xfswxHoi, Tweet: [[{'Tid': 'xfswxHoi', 'user_id': 9999, 'text': 'Tweet xfswxHoi'}]]
# Tweet Id: IRAGeTt7, Tweet: [[{'Tid': 'IRAGeTt7', 'user_id': 9999, 'text': 'Tweet IRAGeTt7'}]]
# Tweet Id: ZRqWBFoW, Tweet: [[{'Tid': 'ZRqWBFoW', 'user_id': 9999, 'text': 'Tweet ZRqWBFoW'}]]
# Tweet Id: IG2Hv4Zl, Tweet: [[{'Tid': 'IG2Hv4Zl', 'user_id': 9999, 'text': 'Tweet IG2Hv4Zl'}]]
# Tweet Id: ZafChHsJ, Tweet: [[{'Tid': 'ZafChHsJ', 'user_id': 9999, 'text': 'Tweet ZafChHsJ'}]]
# Tweet Id: o8CVgk9K, Tweet: [[{'Tid': 'o8CVgk9K', 'user_id': 9999, 'text': 'Tweet o8CVgk9K'}]]
# Tweet Id: nKkNawyA, Tweet: [[{'Tid': 'nKkNawyA', 'user_id': 9999, 'text': 'Tweet nKkNawyA'}]]

# %%
#searching inside cache

# %%
tweetasas = cache.search_tweet('ArRmoLQO')
print(tweetasas)
# Out:
# [{'Tid': 'ArRmoLQO', 'user_id': 9999, 'text': 'Tweet ArRmoLQO'}]

# %%
# Cache integrated with search function example

# %%
# Connect to MongoDB database
import pymongo
from datetime import datetime

mongo_client = pymongo.MongoClient("mongodb+srv://ashtikarshridhar:shridhar@cluster0.ft49nzt.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
mongo_db = mongo_client["Twitter_DB"]
tweet_collection = mongo_db["Tweets"]
quoted_tweet_collection = mongo_db["Quoted-Tweets"]
retweet_collection = mongo_db["Retweets"]

# %%
cache = LRUCache1(capacity=200, checkpoint_interval=300) #Initializing cache with 200 tweets capacity and 5 minutes checkpointing interval

# %%
def search_by_user_name(user_name):
    start_time = time.time()
    cached_tweets = [tweet for tweet in cache.cache.values() if tweet.get("User_Name") == user_name] # Searching in cache
    
    if cached_tweets:
        end_time = time.time()
        runtime = end_time - start_time
        print("Fetched from cache. ")
        print(f"Runtime of my_function: {runtime} seconds")
        return cached_tweets  # If in cache return results from cache
    
    
    tweets = list(tweet_collection.find({"User_Name": user_name}))
    retweets = list(retweet_collection.find({"User_Name": user_name}))
    quoted_tweets = list(quoted_tweet_collection.find({"User_Name": user_name}))

    combined_result = tweets + retweets + quoted_tweets
    end_time = time.time()
    runtime = end_time - start_time
    print("Fetched from Data Base . ")
    print(f"Runtime of my_function: {runtime} seconds")
    cache.process_tweets_for_cache(combined_result) # If not in cache, store in cache
    return combined_result

# %%
search_by_user_name("Gucci Mane") # Getting tweets from a particular user name. 1st time data will load from DB
# Out:
# Fetched from Data Base .
# Runtime of my_function: 0.13840317726135254 seconds
# [{'_id': ObjectId('66249dad7339addd98f6a5a5'),
#   'created_at': '2020-04-12 12:36:30',
#   'Tweet_Id': '1249315454797168641',
#   'Text': 'I pray my haters die of corona virus 😷',
#   'Hashtag': [],
#   'User_Id': '46769281',
#   'User_Name': 'Gucci Mane',
#   'User_Screen_Name': 'gucci1017',
#   'Retweet_Count': 19690,
#   'Quote_count': 5545,
#   'Likes_Count': 75446,
#   'sentiment': 'Negative'}]

# %%
search_by_user_name("Gucci Mane") #Since this result was already fetched and stored previously in cache, it loaded from cache
# Out:
# Fetched from cache.
# Runtime of my_function: 0.0 seconds
# [{'created_at': '2020-04-12 12:36:30',
#   'Tweet_Id': '1249315454797168641',
#   'Text': 'I pray my haters die of corona virus 😷',
#   'Hashtag': [],
#   'User_Id': '46769281',
#   'User_Name': 'Gucci Mane',
#   'User_Screen_Name': 'gucci1017',
#   'Retweet_Count': 19690,
#   'Quote_count': 5545,
#   'Likes_Count': 75446,
#   'sentiment': 'Negative'}]
